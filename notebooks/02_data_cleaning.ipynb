# %%
import numpy as np
import pandas  as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('student_performance_dataset.csv')

# %%
df_clean=df.copy()
df_clean.head()
# Out:
#    student_id  attendance_percentage  assignment_avg  quiz_avg  midterm_score  \
# 0           1                     93              88        74             50
# 1           2                     83              41        67             86
# 2           3                     69              41        43             65
# 3           4                     97              67        77             39
# 4           5                     62              93        88             66
#
#    previous_semester_score  final_score risk_level
# 0                       72        78.35       Safe
# 1                       80        69.30    At Risk
# 2                       70        56.35    At Risk
# 3                       52        70.05       Safe
# 4                       94        80.35       Safe

# %%
df_clean.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_clean.drop_duplicates(inplace=True)

# %%
df_clean.shape
# Out:
# (200, 8)

# %%
df_clean.isnull().sum()
# Out:
# student_id                 0
# attendance_percentage      0
# assignment_avg             0
# quiz_avg                   0
# midterm_score              0
# previous_semester_score    0
# final_score                0
# risk_level                 0
# dtype: int64

# %%
df_clean.dtypes
# Out:
# student_id                   int64
# attendance_percentage        int64
# assignment_avg               int64
# quiz_avg                     int64
# midterm_score                int64
# previous_semester_score      int64
# final_score                float64
# risk_level                  object
# dtype: object

# %%
df_clean['attendance_percentage']=df_clean['attendance_percentage'].clip(0,100)

# %%
df_clean.head()
# Out:
#    student_id  attendance_percentage  assignment_avg  quiz_avg  midterm_score  \
# 0           1                     93              88        74             50
# 1           2                     83              41        67             86
# 2           3                     69              41        43             65
# 3           4                     97              67        77             39
# 4           5                     62              93        88             66
#
#    previous_semester_score  final_score risk_level
# 0                       72        78.35       Safe
# 1                       80        69.30    At Risk
# 2                       70        56.35    At Risk
# 3                       52        70.05       Safe
# 4                       94        80.35       Safe

# %%
df_clean['risk_level_encoded']=df_clean['risk_level'].map({
    'Safe':0,
    'At Risk':1,
    'critical':2
})

# %%
df_clean['risk_level'].unique()
# Out:
# array(['Safe', 'At Risk'], dtype=object)

# %%
df_clean.head()
# Out:
#    student_id  attendance_percentage  assignment_avg  quiz_avg  midterm_score  \
# 0           1                     93              88        74             50
# 1           2                     83              41        67             86
# 2           3                     69              41        43             65
# 3           4                     97              67        77             39
# 4           5                     62              93        88             66
#
#    previous_semester_score  final_score risk_level  risk_level_encoded
# 0                       72        78.35       Safe                   0
# 1                       80        69.30    At Risk                   1
# 2                       70        56.35    At Risk                   1
# 3                       52        70.05       Safe                   0
# 4                       94        80.35       Safe                   0

# %%
df_clean.drop(columns=["student_id"], inplace=True)

# %%
df_clean
# Out:
#      attendance_percentage  assignment_avg  quiz_avg  midterm_score  \
# 0                       93              88        74             50
# 1                       83              41        67             86
# 2                       69              41        43             65
# 3                       97              67        77             39
# 4                       62              93        88             66
# ..                     ...             ...       ...            ...
# 195                     93              66        79             53
# 196                     56              81        45             57
# 197                     57              41        63             82
# 198                     91              65        70             37
# 199                     71              56        59             87
#
#      previous_semester_score  final_score risk_level  risk_level_encoded
# 0                         72        78.35       Safe                   0
# ...

# %%
encoded_df=pd.get_dummies(df_clean,columns=["risk_level"],drop_first=True)

# %%
encoded_df.head()
# Out:
#    attendance_percentage  assignment_avg  quiz_avg  midterm_score  \
# 0                     93              88        74             50
# 1                     83              41        67             86
# 2                     69              41        43             65
# 3                     97              67        77             39
# 4                     62              93        88             66
#
#    previous_semester_score  final_score  risk_level_encoded  risk_level_Safe
# 0                       72        78.35                   0             True
# 1                       80        69.30                   1            False
# 2                       70        56.35                   1            False
# 3                       52        70.05                   0             True
# 4                       94        80.35                   0             True

# %%
df_clean.head()
# Out:
#    attendance_percentage  assignment_avg  quiz_avg  midterm_score  \
# 0                     93              88        74             50
# 1                     83              41        67             86
# 2                     69              41        43             65
# 3                     97              67        77             39
# 4                     62              93        88             66
#
#    previous_semester_score  final_score risk_level  risk_level_encoded
# 0                       72        78.35       Safe                   0
# 1                       80        69.30    At Risk                   1
# 2                       70        56.35    At Risk                   1
# 3                       52        70.05       Safe                   0
# 4                       94        80.35       Safe                   0

# %%
df_clean.to_csv('cleaned_student_data.csv',index=False)

# %%
df_clean.to_csv(r'C:\Users\ASUS\AI-Student-Analytics\data\processed\cleaned_student_data.csv', index=False)
